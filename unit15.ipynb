# %% [markdown]
# # 테이블 형태의 데이터를 쉽게 다루도록 도와주는 pandas 라이브러리

# %%
import pandas as pd
df = pd.read_html('https://ko.wikipedia.org/wiki/%EC%98%AC%EB%A6%BC%ED%94%BD_%EB%A9%94%EB%8B%AC_%EC%A7%91%EA%B3%84')
print(df)
# Out:
# [             국가 (IOC 코드)  하계 참가 횟수  Unnamed: 2  Unnamed: 3  Unnamed: 4      계  \
# 0           아프가니스탄 (AFG)        14           0           0           2      2
# 1              알제리 (ALG)        13           5           4           8     17
# 2            아르헨티나 (ARG)        24          21          25          28     74
# 3            아르메니아 (ARM)         6           2           6           6     14
# 4    오스트랄라시아 (ANZ) [ANZ]         2           3           4           5     12
# ..                   ...       ...         ...         ...         ...    ...
# 148       독립 (IOA) [IOA]         3           1           0           1      2
# 149    독립 참가 (IOP) [IOP]         1           0           1           2      3
# 150  러시아 출신 올림픽 선수 (OAR)         0           0           0           0      0
# 151       혼성 (ZZX) [ZZX]         3           8           5           4     17
# 152                   총합        28        5116        5082        5490  15688
#
# ...

# %%
import pandas as pd
df = pd.read_html('https://ko.wikipedia.org/wiki/%EC%98%AC%EB%A6%BC%ED%94%BD_%EB%A9%94%EB%8B%AC_%EC%A7%91%EA%B3%84')
df[1]
# Out:
#                  국가 (IOC 코드)  하계 참가 횟수  동계 참가 횟수  전체 참가 횟수
# 0                 알바니아 (ALB)         8         4        12
# 1              아메리칸사모아 (ASA)         8         1         9
# 2                  안도라 (AND)        11        12        23
# 3                  앙골라 (ANG)         9         0         9
# 4              앤티가 바부다 (ANT)        10         0        10
# ..                       ...       ...       ...       ...
# 74          중화민국 (ROC) [ROC]         3         0         3
# 75            자르 (SAA) [SAA]         1         0         1
# 76           북예멘 (YAR) [YAR]         2         0         2
# 77  에멘 인민 민주 공화국 (YMD) [YMD]         1         0         1
# 78            난민 (ROT) [ROT]         1         0         1
#
# [79 rows x 4 columns]

# %%
import pandas as pd
df = pd.read_html('https://ko.wikipedia.org/wiki/%EC%98%AC%EB%A6%BC%ED%94%BD_%EB%A9%94%EB%8B%AC_%EC%A7%91%EA%B3%84', header=0, index_col=0)
df[1]
# Out:
#                           하계 참가 횟수  동계 참가 횟수  전체 참가 횟수
# 국가 (IOC 코드)
# 알바니아 (ALB)                       8         4        12
# 아메리칸사모아 (ASA)                    8         1         9
# 안도라 (AND)                       11        12        23
# 앙골라 (ANG)                        9         0         9
# 앤티가 바부다 (ANT)                   10         0        10
# ...                            ...       ...       ...
# 중화민국 (ROC) [ROC]                 3         0         3
# 자르 (SAA) [SAA]                   1         0         1
# 북예멘 (YAR) [YAR]                  2         0         2
# 에멘 인민 민주 공화국 (YMD) [YMD]         1         0         1
# 난민 (ROT) [ROT]                   1         0         1
#
# [79 rows x 3 columns]

# %%
#하계 올림픽 데이터만 추출

summer = df[1].iloc[:,:5] # iloc->데이터 순서에 따라 접근, 콤마 기준 앞은 행, 뒤는 열에 접근
summer
# Out:
#                           하계 참가 횟수  동계 참가 횟수  전체 참가 횟수
# 국가 (IOC 코드)
# 알바니아 (ALB)                       8         4        12
# 아메리칸사모아 (ASA)                    8         1         9
# 안도라 (AND)                       11        12        23
# 앙골라 (ANG)                        9         0         9
# 앤티가 바부다 (ANT)                   10         0        10
# ...                            ...       ...       ...
# 중화민국 (ROC) [ROC]                 3         0         3
# 자르 (SAA) [SAA]                   1         0         1
# 북예멘 (YAR) [YAR]                  2         0         2
# 에멘 인민 민주 공화국 (YMD) [YMD]         1         0         1
# 난민 (ROT) [ROT]                   1         0         1
#
# [79 rows x 3 columns]

# %%
#하계 올림픽 데이터만 추출

summer.columns = ['하계참가횟수','금','은']  #동, 계 부분의 데이터가 안나와서 생략함
summer
# Out:
#                           하계참가횟수   금   은
# 국가 (IOC 코드)
# 알바니아 (ALB)                     8   4  12
# 아메리칸사모아 (ASA)                  8   1   9
# 안도라 (AND)                     11  12  23
# 앙골라 (ANG)                      9   0   9
# 앤티가 바부다 (ANT)                 10   0  10
# ...                          ...  ..  ..
# 중화민국 (ROC) [ROC]               3   0   3
# 자르 (SAA) [SAA]                 1   0   1
# 북예멘 (YAR) [YAR]                2   0   2
# 에멘 인민 민주 공화국 (YMD) [YMD]       1   0   1
# 난민 (ROT) [ROT]                 1   0   1
#
# [79 rows x 3 columns]

# %%
import pandas as pd
df = pd.read_html('https://ko.wikipedia.org/wiki/%EC%98%AC%EB%A6%BC%ED%94%BD_%EB%A9%94%EB%8B%AC_%EC%A7%91%EA%B3%84', header=0, index_col=0)
summer = df[1].iloc[:,:5]
summer.columns = ['하계참가횟수', '금', '은']
print(summer.sort_values('금', ascending=False))
# Out:
#                    하계참가횟수   금   은
# 국가 (IOC 코드)
# 안도라 (AND)              11  12  23
# 산마리노 (SMR)             14  10  24
# 모나코 (MON) [N]          20  10  30
# 보스니아 헤르체고비나 (BIH)       7   7  14
# 볼리비아 (BOL)             14   6  20
# ...                   ...  ..  ..
# 벨리즈 (BIZ) [BIZ]        12   0  12
# 마셜 제도 (MHL)             3   0   3
# 브루나이 (BRU) [A]          5   0   5
# 미크로네시아 연방 (FSM)         5   0   5
# 난민 (ROT) [ROT]          1   0   1
#
# [79 rows x 3 columns]

# %%
summer.to_excel('하계올림픽메달.xlsx')

# %% [markdown]
# ### pands란? ->panel datas(패널 자료)
# #### numpy기반, 1차원 배열 형태의 데이터 구조 -> series, 2차원 배열 형태의 데이터 구조 -> dataframe

# %%
import pandas as pd
index = pd.date_range('1/1/2000', periods=8)
print(index)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df
# Out:
#                    A         B         C
# 2000-01-01  0.128622  0.168739  0.741098
# 2000-01-02  0.205955  0.380226  0.609963
# 2000-01-03  0.795942  0.483309  0.946423
# 2000-01-04  0.860973  0.070548  0.186575
# 2000-01-05  0.062354  0.662902  0.184764
# 2000-01-06  0.749389  0.359024  0.187991
# 2000-01-07  0.406788  0.764955  0.642210
# 2000-01-08  0.496687  0.407223  0.809426

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
print(df['B'])
# Out:
# 2000-01-01    0.272865
# 2000-01-02    0.031194
# 2000-01-03    0.863724
# 2000-01-04    0.190994
# 2000-01-05    0.933430
# 2000-01-06    0.551379
# 2000-01-07    0.111407
# 2000-01-08    0.676532
# Freq: D, Name: B, dtype: float64

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
print(df['B']>0.4)
# Out:
# 2000-01-01     True
# 2000-01-02     True
# 2000-01-03     True
# 2000-01-04    False
# 2000-01-05    False
# 2000-01-06    False
# 2000-01-07     True
# 2000-01-08     True
# Freq: D, Name: B, dtype: bool

# %%
df2 = df[df['B']>0.4]
df2
# Out:
#                    A         B         C
# 2000-01-01  0.367205  0.429232  0.904452
# 2000-01-02  0.843770  0.715251  0.205513
# 2000-01-03  0.896448  0.497470  0.727079
# 2000-01-07  0.347245  0.885808  0.275996
# 2000-01-08  0.551757  0.490353  0.816976

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A'] /df['B']
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.742668  0.871976  0.068012  0.851707
# 2000-01-02  0.939641  0.672966  0.991500  1.396268
# 2000-01-03  0.107262  0.835228  0.571436  0.128422
# 2000-01-04  0.810854  0.089646  0.131056  9.045075
# 2000-01-05  0.953758  0.620583  0.507411  1.536873
# 2000-01-06  0.019406  0.206229  0.023687  0.094098
# 2000-01-07  0.600166  0.498836  0.621517  1.203134
# 2000-01-08  0.232460  0.814904  0.409804  0.285260

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A'] /df['B'] # 행방향 축을 기준으로 계산
df['E'] = np.sum(df, axis=1) # 열방향 축을 기준으로 계산
df.head() #처음 5개의  데이터만 확인
# Out:
#                    A         B         C         D         E
# 2000-01-01  0.086386  0.097491  0.812244  0.886089  1.882210
# 2000-01-02  0.002669  0.738617  0.045409  0.003613  0.790309
# 2000-01-03  0.316369  0.116690  0.710283  2.711198  3.854540
# 2000-01-04  0.030829  0.790611  0.899527  0.038994  1.759961
# 2000-01-05  0.735693  0.829253  0.202804  0.887176  2.654925

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A'] /df['B'] # 행방향 축을 기준으로 계산
df['E'] = np.sum(df, axis=1) # 열방향 축을 기준으로 계산
df = df.sub(df['A'], axis=0) # 전체 데이터를 A열의 값으로 빼기
df.head() #처음 5개의  데이터만 확인
# Out:
#               A         B         C          D          E
# 2000-01-01  0.0 -0.440728 -0.842009   0.876853   2.487726
# 2000-01-02  0.0 -0.938804 -0.810353  16.997173  18.230186
# 2000-01-03  0.0 -0.255390 -0.112348   2.481573   3.289000
# 2000-01-04  0.0 -0.357877  0.217993  53.307076  54.261205
# 2000-01-05  0.0  0.216813 -0.272851   0.188150   1.680041

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A'] /df['B'] # 행방향 축을 기준으로 계산
df['E'] = np.sum(df, axis=1) # 열방향 축을 기준으로 계산
df = df.sub(df['A'], axis=0) # 전체 데이터를 A열의 값으로 빼기
df = df.div(df['C'], axis=0) #C열 데이터를 기준으로 열 우선 계산
df.to_csv('test.csv')
df.head() #처음 5개의  데이터만 확인
# Out:
#               A         B    C           D           E
# 2000-01-01  0.0  0.611321  1.0    0.214347    2.138200
# 2000-01-02 -0.0  0.160069  1.0   -0.831775   -5.886572
# 2000-01-03  0.0 -0.859818  1.0  122.442194  125.214212
# 2000-01-04  0.0 -0.379260  1.0    5.004852    7.199725
# 2000-01-05  0.0  1.658541  1.0    0.098343    4.526744
